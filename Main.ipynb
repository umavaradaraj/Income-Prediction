# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\Uma\Desktop\ML_Project\income.csv')

# %%
df
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 4       18             ?  103497  Some-college               10
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation relationship   race  gender  \
# 0           Never-married  Machine-op-inspct    Own-child  Black    Male
# ...

# %%
df.education.value_counts()
# Out:
# HS-grad         15784
# Some-college    10878
# Bachelors        8025
# Masters          2657
# Assoc-voc        2061
# 11th             1812
# Assoc-acdm       1601
# 10th             1389
# 7th-8th           955
# Prof-school       834
# 9th               756
# 12th              657
# Doctorate         594
# 5th-6th           509
# 1st-4th           247
# Preschool          83
# Name: education, dtype: int64

# %%
df.occupation.value_counts()
# Out:
# Prof-specialty       6172
# Craft-repair         6112
# Exec-managerial      6086
# Adm-clerical         5611
# Sales                5504
# Other-service        4923
# Machine-op-inspct    3022
# ?                    2809
# Transport-moving     2355
# Handlers-cleaners    2072
# Farming-fishing      1490
# Tech-support         1446
# Protective-serv       983
# Priv-house-serv       242
# Armed-Forces           15
# Name: occupation, dtype: int64

# %%
df= pd.concat([df.drop('occupation',axis=1),pd.get_dummies(df['occupation']).add_prefix('occupation_')],axis=1)
df= pd.concat([df.drop('workclass',axis=1),pd.get_dummies(df['workclass']).add_prefix('workclass_')],axis=1)
df= df.drop('education',axis=1)
df= pd.concat([df.drop('marital-status',axis=1),pd.get_dummies(df['marital-status']).add_prefix('marital-status_')],axis=1)
df= pd.concat([df.drop('relationship',axis=1),pd.get_dummies(df['relationship']).add_prefix('relationship_')],axis=1)
df= pd.concat([df.drop('race',axis=1),pd.get_dummies(df['race']).add_prefix('race_')],axis=1)
df= pd.concat([df.drop('native-country',axis=1),pd.get_dummies(df['native-country']).add_prefix('native-country_')],axis=1)

# %%
df
# Out:
#        age  fnlwgt  educational-num  gender  capital-gain  capital-loss  \
# 0       25  226802                7    Male             0             0
# 1       38   89814                9    Male             0             0
# 2       28  336951               12    Male             0             0
# 3       44  160323               10    Male          7688             0
# 4       18  103497               10  Female             0             0
# ...    ...     ...              ...     ...           ...           ...
# 48837   27  257302               12  Female             0             0
# 48838   40  154374                9    Male             0             0
# 48839   58  151910                9  Female             0             0
# 48840   22  201490                9    Male             0             0
# 48841   52  287927                9  Female         15024             0
#
#        hours-per-week income  occupation_?  occupation_Adm-clerical  ...  \
# ...

# %%
df['gender'] = df['gender'].apply(lambda x: 1 if x == 'Male' else 0)
df['income'] = df['income'].apply(lambda x: 1 if x == '>50K' else 0)

# %%
df.columns.values
# Out:
# array(['age', 'fnlwgt', 'educational-num', 'gender', 'capital-gain',
#        'capital-loss', 'hours-per-week', 'income', 'occupation_?',
#        'occupation_Adm-clerical', 'occupation_Armed-Forces',
#        'occupation_Craft-repair', 'occupation_Exec-managerial',
#        'occupation_Farming-fishing', 'occupation_Handlers-cleaners',
#        'occupation_Machine-op-inspct', 'occupation_Other-service',
#        'occupation_Priv-house-serv', 'occupation_Prof-specialty',
#        'occupation_Protective-serv', 'occupation_Sales',
#        'occupation_Tech-support', 'occupation_Transport-moving',
#        'workclass_?', 'workclass_Federal-gov', 'workclass_Local-gov',
#        'workclass_Never-worked', 'workclass_Private',
#        'workclass_Self-emp-inc', 'workclass_Self-emp-not-inc',
#        'workclass_State-gov', 'workclass_Without-pay',
#        'marital-status_Divorced', 'marital-status_Married-AF-spouse',
#        'marital-status_Married-civ-spouse',
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize= (18,12))
sns.heatmap(df.corr(),annot=False,cmap='coolwarm')
# Out:
# <AxesSubplot:>

# %%
df.corr()
# Out:
#                                      age    fnlwgt  educational-num    gender  \
# age                             1.000000 -0.076628         0.030940  0.088120
# fnlwgt                         -0.076628  1.000000        -0.038761  0.027739
# educational-num                 0.030940 -0.038761         1.000000  0.009328
# gender                          0.088120  0.027739         0.009328  1.000000
# capital-gain                    0.077229 -0.003706         0.125146  0.047094
# ...                                  ...       ...              ...       ...
# native-country_Thailand        -0.001766 -0.001512         0.007283 -0.007117
# native-country_Trinadad&Tobago  0.001056  0.004153        -0.010201 -0.009342
# native-country_United-States    0.011888 -0.070645         0.104210 -0.011167
# native-country_Vietnam         -0.012337 -0.007479        -0.007544 -0.001545
# native-country_Yugoslavia       0.002905  0.004699        -0.005798  0.005262
#
# ...

# %%
correlations = df.corr()['income'].abs()
sorted_correlations = correlations.sort_values()
num_cols_to_drop = int (0.8 * len(df.columns))
cols_to_drop = sorted_correlations.iloc[:num_cols_to_drop].index
df_dropped = df.drop(cols_to_drop, axis =1)

# %%
df_dropped
# Out:
#        age  educational-num  gender  capital-gain  capital-loss  \
# 0       25                7       1             0             0
# 1       38                9       1             0             0
# 2       28               12       1             0             0
# 3       44               10       1          7688             0
# 4       18               10       0             0             0
# ...    ...              ...     ...           ...           ...
# 48837   27               12       0             0             0
# 48838   40                9       1             0             0
# 48839   58                9       0             0             0
# 48840   22                9       1             0             0
# 48841   52                9       0         15024             0
#
#        hours-per-week  income  occupation_Exec-managerial  \
# 0                  40       0                           0
# 1                  50       0                           0
# ...

# %%
plt.figure(figsize= (15,10))
sns.heatmap(df_dropped.corr(),annot=True,cmap='coolwarm')
# Out:
# <AxesSubplot:>

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split

df= df.drop('fnlwgt',axis=1)
train_df,test_df =train_test_split(df, test_size=0.2)

# %%
train_df
# Out:
#        age  educational-num  gender  capital-gain  capital-loss  \
# 42343   23               10       0             0             0
# 8602    24               11       0             0             0
# 42472   31                9       1             0             0
# 32514   37                9       1             0             0
# 37713   39                9       0             0             0
# ...    ...              ...     ...           ...           ...
# 41588   51                6       0             0             0
# 17766   31                6       1          2105             0
# 47096   54               13       1         27828             0
# 34472   57                9       0             0             0
# 2158    26                9       1             0             0
#
#        hours-per-week  income  occupation_?  occupation_Adm-clerical  \
# 42343              40       0             0                        0
# ...

# %%
test_df
# Out:
#        age  educational-num  gender  capital-gain  capital-loss  \
# 25009   41                9       1             0             0
# 24572   17                7       1             0             0
# 46621   57                9       1             0             0
# 45282   22                7       1             0             0
# 4942    48               13       1             0             0
# ...    ...              ...     ...           ...           ...
# 39058   28                9       0             0             0
# 3658    30                9       1             0             0
# 9947    24               12       1             0             0
# 38453   23               11       0             0             0
# 8593    40                9       0             0             0
#
#        hours-per-week  income  occupation_?  occupation_Adm-clerical  \
# 25009              40       0             0                        0
# ...

# %%
train_X = train_df.drop('income', axis =1)
train_Y = train_df['income']

test_X = test_df.drop('income', axis =1)
test_Y = test_df['income']

# %%
forest = RandomForestClassifier()
forest.fit(train_X,train_Y)
# Out:
# RandomForestClassifier()

# %%
forest.score(test_X,test_Y)
# Out:
# 0.8495240045040434

# %%
forest.feature_importances_
# Out:
# array([2.29241926e-01, 1.29349556e-01, 1.34828536e-02, 1.14429920e-01,
#        3.70943905e-02, 1.15644205e-01, 1.87034944e-03, 5.23630893e-03,
#        1.04293453e-05, 6.39189077e-03, 1.98149368e-02, 5.01550545e-03,
#        3.51457415e-03, 4.16947810e-03, 8.01523111e-03, 1.85895665e-04,
#        1.78749074e-02, 3.10688852e-03, 5.97101705e-03, 4.25634363e-03,
#        4.52946390e-03, 1.60955789e-03, 4.81354951e-03, 5.64011915e-03,
#        2.56094483e-06, 9.51434298e-03, 6.38244436e-03, 8.56400788e-03,
#        4.62544178e-03, 1.11419555e-04, 7.83753022e-03, 2.46077031e-04,
#        5.98662025e-02, 1.02123456e-03, 2.46637677e-02, 1.94207883e-03,
#        1.77455782e-03, 5.26580279e-02, 1.28762634e-02, 1.56208175e-03,
#        5.82636047e-03, 6.06909251e-03, 9.14225687e-03, 1.38051172e-03,
#        2.86883723e-03, 4.72239789e-03, 9.48974302e-04, 6.15667010e-03,
#        2.85264582e-03, 3.08391353e-04, 1.35977506e-03, 6.18881333e-04,
# ...

# %%
forest.feature_names_in_
# Out:
# array(['age', 'educational-num', 'gender', 'capital-gain', 'capital-loss',
#        'hours-per-week', 'occupation_?', 'occupation_Adm-clerical',
#        'occupation_Armed-Forces', 'occupation_Craft-repair',
#        'occupation_Exec-managerial', 'occupation_Farming-fishing',
#        'occupation_Handlers-cleaners', 'occupation_Machine-op-inspct',
#        'occupation_Other-service', 'occupation_Priv-house-serv',
#        'occupation_Prof-specialty', 'occupation_Protective-serv',
#        'occupation_Sales', 'occupation_Tech-support',
#        'occupation_Transport-moving', 'workclass_?',
#        'workclass_Federal-gov', 'workclass_Local-gov',
#        'workclass_Never-worked', 'workclass_Private',
#        'workclass_Self-emp-inc', 'workclass_Self-emp-not-inc',
#        'workclass_State-gov', 'workclass_Without-pay',
#        'marital-status_Divorced', 'marital-status_Married-AF-spouse',
#        'marital-status_Married-civ-spouse',
#        'marital-status_Married-spouse-absent',
# ...

# %%
importances = dict(zip(forest.feature_importances_,forest.feature_names_in_))
importances = {k:v for k,v in sorted(importances.items(), key = lambda x:x[1])}

# %%
importances
# Out:
# {0.22924192580521616: 'age',
#  0.11442992028779801: 'capital-gain',
#  0.03709439045699123: 'capital-loss',
#  0.12934955561597272: 'educational-num',
#  0.013482853619331084: 'gender',
#  0.11564420464138057: 'hours-per-week',
#  0.007837530224894574: 'marital-status_Divorced',
#  0.0002460770307687603: 'marital-status_Married-AF-spouse',
#  0.05986620252789369: 'marital-status_Married-civ-spouse',
#  0.0010212345645353481: 'marital-status_Married-spouse-absent',
#  0.024663767699417406: 'marital-status_Never-married',
#  0.0019420788309602918: 'marital-status_Separated',
#  0.0017745578224996241: 'marital-status_Widowed',
#  0.002852645823778361: 'native-country_?',
#  0.0003083913533807966: 'native-country_Cambodia',
#  0.001359775059299467: 'native-country_Canada',
#  0.0006188813331026555: 'native-country_China',
#  0.0003128194908283809: 'native-country_Columbia',
#  0.0008400596633430831: 'native-country_Cuba',
#  0.00030527447688896464: 'native-country_Dominican-Republic',
# ...

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {
    'n_estimators' : [50,100,250],
    'max_depth' : [5,10,30,None],
    'min_samples_split' :[2,4],
    'max_features' :['sqrt','log2']
}

grid_search = GridSearchCV(estimator= RandomForestClassifier(),
                          param_grid= param_grid, verbose =10)

# %%
grid_search.fit(train_X,train_Y)
# Out:
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# [CV 1/5; 1/48] START max_depth=5, max_features=sqrt, min_samples_split=2, n_estimators=50
# [CV 1/5; 1/48] END max_depth=5, max_features=sqrt, min_samples_split=2, n_estimators=50;, score=0.835 total time=   1.3s
# [CV 2/5; 1/48] START max_depth=5, max_features=sqrt, min_samples_split=2, n_estimators=50
# [CV 2/5; 1/48] END max_depth=5, max_features=sqrt, min_samples_split=2, n_estimators=50;, score=0.844 total time=   1.2s
# [CV 3/5; 1/48] START max_depth=5, max_features=sqrt, min_samples_split=2, n_estimators=50
# [CV 3/5; 1/48] END max_depth=5, max_features=sqrt, min_samples_split=2, n_estimators=50;, score=0.834 total time=   1.3s
# [CV 4/5; 1/48] START max_depth=5, max_features=sqrt, min_samples_split=2, n_estimators=50
# [CV 4/5; 1/48] END max_depth=5, max_features=sqrt, min_samples_split=2, n_estimators=50;, score=0.829 total time=   1.4s
# ...

# %%
grid_search.best_estimator_
# Out:
# RandomForestClassifier(max_depth=30, max_features='sqrt', min_samples_split=4,
#                        n_estimators=250)

# %%
forest = grid_search.best_estimator_

# %%
forest.score(test_X,test_Y)
# Out:
# 0.8626266762206981

# %%
importances = dict(zip(forest.feature_importances_,forest.feature_names_in_))
importances = {k:v for k,v in sorted(importances.items(), key = lambda x:x[1])}

# %%
importances
# Out:
# {0.14953723731499918: 'age',
#  0.13935410865593786: 'capital-gain',
#  0.043886207825325194: 'capital-loss',
#  0.13104852217843158: 'educational-num',
#  0.01487341351552911: 'gender',
#  0.09159089617917623: 'hours-per-week',
#  0.006702924455062285: 'marital-status_Divorced',
#  0.00026550506416015427: 'marital-status_Married-AF-spouse',
#  0.09160638161790437: 'marital-status_Married-civ-spouse',
#  0.0011076933276946142: 'marital-status_Married-spouse-absent',
#  0.028719235069838107: 'marital-status_Never-married',
#  0.001985070977457851: 'marital-status_Separated',
#  0.0018643252663292167: 'marital-status_Widowed',
#  0.002888873012155996: 'native-country_?',
#  0.00035433613197791223: 'native-country_Cambodia',
#  0.0015155483979357868: 'native-country_Canada',
#  0.0006100026507578995: 'native-country_China',
#  0.0003850401594704037: 'native-country_Columbia',
#  0.0008905237889353817: 'native-country_Cuba',
# ...
